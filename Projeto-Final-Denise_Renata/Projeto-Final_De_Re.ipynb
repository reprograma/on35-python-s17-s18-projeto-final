# %%
import pandas as pd

# %%
import pandas as pd
dfSaresp = pd.read_csv('Dados_Saresp_2023.csv',delimiter=';', encoding='utf-8', skiprows=8)

# %%
dfSaresp.head()
# Out:
#    1  1.1  Rede Estadual  1.2  100   SAO PAULO  9º Ano EF  2  TARDE  2.1  \
# 0  1    1  Rede Estadual    1  100   SAO PAULO  9º Ano EF  9  GERAL    2
# 1  1    1  Rede Estadual    5  150  ADAMANTINA  9º Ano EF  1  MANHÃ    2
# 2  1    1  Rede Estadual    5  150  ADAMANTINA  9º Ano EF  9  GERAL    2
# 3  1    1  Rede Estadual    5  152       AGUAI  2º Ano EF  1  MANHÃ    2
# 4  1    1  Rede Estadual    5  152       AGUAI  2º Ano EF  9  GERAL    2
#
#    MATEMÁTICA  238,8
# 0  MATEMÁTICA    242
# 1  MATEMÁTICA  255,8
# 2  MATEMÁTICA  255,8
# 3  MATEMÁTICA  164,4
# 4  MATEMÁTICA  164,4

# %%
dfSaresp.tail()
# Out:
#       1  1.1   Rede Estadual  1.2  100            SAO PAULO  9º Ano EF  2  \
# 5400  2    2  Rede Municipal    5  793  RIBEIRAO DOS INDIOS  5º Ano EF  9
# 5401  2    2  Rede Municipal    5  794              TRABIJU  2º Ano EF  2
# 5402  2    2  Rede Municipal    5  794              TRABIJU  2º Ano EF  9
# 5403  2    2  Rede Municipal    5  794              TRABIJU  5º Ano EF  2
# 5404  2    2  Rede Municipal    5  794              TRABIJU  5º Ano EF  9
#
#       TARDE  2.1  MATEMÁTICA  238,8
# 5400  GERAL    2  MATEMÁTICA  214,6
# 5401  TARDE    2  MATEMÁTICA    230
# 5402  GERAL    2  MATEMÁTICA    230
# 5403  TARDE    2  MATEMÁTICA  217,5
# 5404  GERAL    2  MATEMÁTICA  217,5

# %%
print(dfSaresp.shape)
# Out:
# (5405, 12)

# %%
nulos_por_coluna = dfSaresp.isnull().sum()
print(nulos_por_coluna)
# Out:
# 1                0
# 1.1              0
# Rede Estadual    0
# 1.2              0
# 100              0
# SAO PAULO        0
# 9º Ano EF        0
# 2                0
# TARDE            0
# 2.1              0
# MATEMÁTICA       0
# 238,8            0
# dtype: int64

# %%
dfSaresp.columns
# Out:
# Index(['1', '1.1', 'Rede Estadual', '1.2', '100', 'SAO PAULO', '9º Ano EF',
#        '2', 'TARDE', '2.1', 'MATEMÁTICA', '238,8'],
#       dtype='object')

# %%
dfSaresp.columns = dfSaresp.columns.str.strip()

# %%
dfSaresp.columns = ['DEPADM', 
', DEPBOL', 'NOMEDEPBOL', 'CODRMET', 'CODMUN', 'MUN', 'SERIE_ANO', 'COD_PER', 'PERIODO', 'CO_COMP', 'DS_COMP', 'MEDPROF']

# %%
dfSaresp.columns
# Out:
# Index(['DEPADM', ', DEPBOL', 'NOMEDEPBOL', 'CODRMET', 'CODMUN', 'MUN',
#        'SERIE_ANO', 'COD_PER', 'PERIODO', 'CO_COMP', 'DS_COMP', 'MEDPROF'],
#       dtype='object')

# %%
dfSaresp.head()
# Out:
#    DEPADM  , DEPBOL     NOMEDEPBOL  CODRMET  CODMUN         MUN  SERIE_ANO  \
# 0       1         1  Rede Estadual        1     100   SAO PAULO  9º Ano EF
# 1       1         1  Rede Estadual        5     150  ADAMANTINA  9º Ano EF
# 2       1         1  Rede Estadual        5     150  ADAMANTINA  9º Ano EF
# 3       1         1  Rede Estadual        5     152       AGUAI  2º Ano EF
# 4       1         1  Rede Estadual        5     152       AGUAI  2º Ano EF
#
#    COD_PER PERIODO  CO_COMP     DS_COMP MEDPROF
# 0        9   GERAL        2  MATEMÁTICA     242
# 1        1   MANHÃ        2  MATEMÁTICA   255,8
# 2        9   GERAL        2  MATEMÁTICA   255,8
# 3        1   MANHÃ        2  MATEMÁTICA   164,4
# 4        9   GERAL        2  MATEMÁTICA   164,4

# %%
dfSaresp = dfSaresp.drop(['DEPADM', ', DEPBOL', 'CODRMET', 'CODMUN', 'COD_PER', 'CO_COMP'], axis=1)

# %%
dfSaresp.head()
# Out:
#       NOMEDEPBOL         MUN  SERIE_ANO PERIODO     DS_COMP MEDPROF
# 0  Rede Estadual   SAO PAULO  9º Ano EF   GERAL  MATEMÁTICA     242
# 1  Rede Estadual  ADAMANTINA  9º Ano EF   MANHÃ  MATEMÁTICA   255,8
# 2  Rede Estadual  ADAMANTINA  9º Ano EF   GERAL  MATEMÁTICA   255,8
# 3  Rede Estadual       AGUAI  2º Ano EF   MANHÃ  MATEMÁTICA   164,4
# 4  Rede Estadual       AGUAI  2º Ano EF   GERAL  MATEMÁTICA   164,4

# %%
dfSaresp = dfSaresp.rename(columns={
    'NOMEDEPBOL': 'REDE DE ENSINO', 
    'MUN': 'MUNICIPIO', 
    'DS_COMP': 'COMPONENTE_CURRICULAR', 
    'MEDPROF': 'MEDIA_PROFICIENCIA'
})

# %%
dfSaresp.head()
# Out:
#   REDE DE ENSINO   MUNICIPIO  SERIE_ANO PERIODO COMPONENTE_CURRICULAR  \
# 0  Rede Estadual   SAO PAULO  9º Ano EF   GERAL            MATEMÁTICA
# 1  Rede Estadual  ADAMANTINA  9º Ano EF   MANHÃ            MATEMÁTICA
# 2  Rede Estadual  ADAMANTINA  9º Ano EF   GERAL            MATEMÁTICA
# 3  Rede Estadual       AGUAI  2º Ano EF   MANHÃ            MATEMÁTICA
# 4  Rede Estadual       AGUAI  2º Ano EF   GERAL            MATEMÁTICA
#
#   MEDIA_PROFICIENCIA
# 0                242
# 1              255,8
# 2              255,8
# 3              164,4
# 4              164,4

# %%
dfSaresp.dtypes
# Out:
# REDE DE ENSINO           object
# MUNICIPIO                object
# SERIE_ANO                object
# PERIODO                  object
# COMPONENTE_CURRICULAR    object
# MEDIA_PROFICIENCIA       object
# dtype: object

# %%
# Substituir vírgulas por pontos para interpretar como decimais
dfSaresp['MEDIA_PROFICIENCIA'] = dfSaresp['MEDIA_PROFICIENCIA'].str.replace(',', '.')

# Converter a coluna para numérico (float)
dfSaresp['MEDIA_PROFICIENCIA'] = pd.to_numeric(dfSaresp['MEDIA_PROFICIENCIA'], errors='coerce')

# %%
# Valor mínimo considerando apenas valores maiores que 100
minimo = dfSaresp['MEDIA_PROFICIENCIA'][dfSaresp['MEDIA_PROFICIENCIA'] > 100].min()

# Valor máximo
maximo = dfSaresp['MEDIA_PROFICIENCIA'].max()

# Soma dos valores
soma = dfSaresp['MEDIA_PROFICIENCIA'].sum()

# Média dos valores
media = dfSaresp['MEDIA_PROFICIENCIA'].mean()

print(f"""Menor Média Saresp 2023: {minimo}
Maior Média Saresp 2023: {maximo}
Soma das Médias: {soma}
Média de Proficiência Saresp: {media}""")
# Out:
# Menor Média Saresp 2023: 111.3
# Maior Média Saresp 2023: 313.8
# Soma das Médias: 1126245.5999999999
# Média de Proficiência Saresp: 208.3710638297872

# %%
import matplotlib.pyplot as plt

# Dados a serem plotados (média, máximo, mínimo)
valores = [media, maximo, minimo]
labels = ['Média', 'Máximo', 'Mínimo']

# Criar o gráfico de barras
plt.figure(figsize=(8, 5))
plt.bar(labels, valores, color=['skyblue', 'green', 'red'])

# Adicionar título e rótulos
plt.title('Média, Máximo e Mínimo da Proficiência Saresp 2023')
plt.ylabel('Valores')

# Exibir o gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Dados dos municípios e seus níveis de desempenho
municipios = ['Município A', 'Município B', 'Município C', 'Município D']
desempenho = [75, 85, 90, 80]  # Exemplo de resultados de desempenho

# Criar o gráfico de linhas
plt.figure(figsize=(10, 6))
plt.plot(municipios, desempenho, marker='o', linestyle='-', color='purple')

# Adicionar título e rótulos
plt.title('Nível de Desempenho por Município (Prova de Proficiência)')
plt.xlabel('Municípios')
plt.ylabel('Nível de Desempenho')

# Exibir o gráfico
plt.show()

# Dados dos municípios e seus níveis de desempenho
municipios = ['Município A', 'Município B', 'Município C', 'Município D']
desempenho = [75, 85, 90, 80]  # Exemplo de resultados de desempenho

# Criar o gráfico de linhas
plt.figure(figsize=(10, 6))
plt.plot(municipios, desempenho, marker='o', linestyle='-', color='purple')

# Adicionar título e rótulos
plt.title('Nível de Desempenho por Município (Prova de Proficiência)')
plt.xlabel('Municípios')
plt.ylabel('Nível de Desempenho')

# Exibir o gráfico
plt.show()

# %%
# Calcular a média de proficiência por tipo de rede
media_por_rede = dfSaresp.groupby('REDE DE ENSINO')['MEDIA_PROFICIENCIA'].mean()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Criar gráfico de barras
plt.figure(figsize=(8, 5))
media_por_rede.plot(kind='bar', color=['blue', 'orange'])

# Adicionar título e rótulos
plt.title('Comparação da Média de Proficiência SARESP 2023: Rede Estadual vs Rede Municipal')
plt.ylabel('Média de Proficiência por Rede de Ensino')
plt.xlabel('MODADALIDADE DE REDE DE ENSINO')

# Adicionar valores em cima das barras
for index, value in enumerate(media_por_rede):
    plt.text(index, value, round(value, 2), ha='center', va='bottom')

# Exibir o gráfico
plt.xticks(rotation=0)  # Para manter os rótulos na horizontal
plt.tight_layout()  # Para ajustar o layout
plt.show()

# %%
import pandas as pd
dfCeara = pd.read_csv('Dados_Ceara_2012_2023.csv',delimiter=';', encoding='utf-8', skiprows=8)

# %%
dfCeara.head()
# Out:
#    9  9º Ano do Ensino Fundamental  1  ESTADUAL  3   ACARAU  2300200  \
# 0  9  9º Ano do Ensino Fundamental  1  ESTADUAL  4  CAMOCIM  2304707
# 1  9  9º Ano do Ensino Fundamental  1  ESTADUAL  5  TIANGUA  2305001
# 2  9  9º Ano do Ensino Fundamental  1  ESTADUAL  5  TIANGUA  2305308
# 3  9  9º Ano do Ensino Fundamental  1  ESTADUAL  5  TIANGUA  2312304
# 4  9  9º Ano do Ensino Fundamental  1  ESTADUAL  6   SOBRAL  2312007
#
#               ACARAU.1  2012  259,6333763  ...  93,90243902 -.1 -.2 -.3 -.4  \
# 0               GRANJA  2012  232,8831856  ...  93,67088608   -   -   -   -
# 1  GUARACIABA DO NORTE  2012  257,5044074  ...  97,61904762   -   -   -   -
# 2             IBIAPINA  2012  251,5616565  ...   93,5483871   -   -   -   -
# 3         SAO BENEDITO  2012  259,7284422  ...  91,58878505   -   -   -   -
# 4    SANTANA DO ACARAU  2012   246,787892  ...  83,78378378   -   -   -   -
#
#   -.5  -.6  -.7 -.8 -.9
# 0   -    -    -   -   -
# 1   -    -    -   -   -
# 2   -    -    -   -   -
# 3   -    -    -   -   -
# 4   -    -    -   -   -
#
# [5 rows x 29 columns]

# %%
dfCeara.tail()
# Out:
#       9  9º Ano do Ensino Fundamental  1 ESTADUAL   3       ACARAU  2300200  \
# 2878  9  9º Ano do Ensino Fundamental  3  PÚBLICA  20  BREJO SANTO  2308302
# 2879  9  9º Ano do Ensino Fundamental  3  PÚBLICA  20  BREJO SANTO  2308401
# 2880  9  9º Ano do Ensino Fundamental  3  PÚBLICA  20  BREJO SANTO  2310605
# 2881  9  9º Ano do Ensino Fundamental  3  PÚBLICA  20  BREJO SANTO  2311108
# 2882  9  9º Ano do Ensino Fundamental  3  PÚBLICA  21    FORTALEZA  2304400
#
#           ACARAU.1  2012  259,6333763  ...  93,90243902          -.1  \
# 2878      MILAGRES  2023  251,2160007  ...  101,0948905            1
# 2879  MISSAO VELHA  2023  240,0978556  ...  99,00398406  0,990039841
# 2880     PENAFORTE  2023  251,4668045  ...  97,77777778  0,977777778
# 2881     PORTEIRAS  2023  266,9183916  ...  101,8518519            1
# 2882     FORTALEZA  2023  243,2660844  ...  100,5217637            1
#
#               -.2          -.3   -.4   -.5   -.6   -.7          -.8  \
# 2878  3,810800035  0,510830325   102    84    68    23   1,94667222
# 2879  3,254892778  0,463279678   227   150    86    34  1,492906498
# 2880  3,823340223  0,524621212    43    47    28    14  1,961231929
# 2881  4,595919581  0,594318182    50    69    69    32  2,731438569
# 2882  3,413304218  0,475216273  8256  8007  4108  1014  1,622057709
#
#               -.9
# 2878  2,698013756
# 2879  2,052290919
# 2880  2,587962577
# 2881  3,335823464
# 2882  2,603981615
#
# [5 rows x 29 columns]

# %%
dfCeara.columns = dfCeara.columns.str.strip()

# %%
print(len(dfCeara.columns))
# Out:
# 29

# %%
dfCeara.columns = [
    'Código da Etapa', 'Etapa', 'Código da Rede', 'Rede', 'Código da CREDE', 
    'CREDE', 'Código do Município', 'Município', 'Edição', 'Proficiência Média', 
    'Desvio Padrão', 'Indicação do Padrão de Desempenho', 'Muito Crítico', 
    'Crítico', 'Intermediário', 'Adequado', 'População', 'Alunos Efetivos', 
    'Alunos Efetivos (Ponderado)¹', 'Percentual de Participação (Ponderado)¹', 
    'Taxa de Participação', 'Proficiência Padronizada', 'Fator de Ajuste', 
    'Número de Alunos no Muito Crítico', 'Número de Alunos no Crítico', 
    'Número de Alunos no Intermediário', 'Número de Alunos no Adequado', 
    'IDE EF MT', 'IDE Médio EF'
]

# %%
dfCeara.head()
# Out:
#    Código da Etapa                         Etapa  Código da Rede      Rede  \
# 0                9  9º Ano do Ensino Fundamental               1  ESTADUAL
# 1                9  9º Ano do Ensino Fundamental               1  ESTADUAL
# 2                9  9º Ano do Ensino Fundamental               1  ESTADUAL
# 3                9  9º Ano do Ensino Fundamental               1  ESTADUAL
# 4                9  9º Ano do Ensino Fundamental               1  ESTADUAL
#
#   Código da CREDE    CREDE Código do Município            Município Edição  \
# 0               4  CAMOCIM             2304707               GRANJA   2012
# 1               5  TIANGUA             2305001  GUARACIABA DO NORTE   2012
# 2               5  TIANGUA             2305308             IBIAPINA   2012
# 3               5  TIANGUA             2312304         SAO BENEDITO   2012
# 4               6   SOBRAL             2312007    SANTANA DO ACARAU   2012
#
#   Proficiência Média  ... Percentual de Participação (Ponderado)¹  \
# 0        232,8831856  ...                             93,67088608
# 1        257,5044074  ...                             97,61904762
# 2        251,5616565  ...                              93,5483871
# 3        259,7284422  ...                             91,58878505
# 4         246,787892  ...                             83,78378378
#
#   Taxa de Participação Proficiência Padronizada Fator de Ajuste  \
# 0                    -                        -               -
# 1                    -                        -               -
# 2                    -                        -               -
# 3                    -                        -               -
# 4                    -                        -               -
#
#   Número de Alunos no Muito Crítico Número de Alunos no Crítico  \
# 0                                 -                           -
# 1                                 -                           -
# 2                                 -                           -
# 3                                 -                           -
# 4                                 -                           -
#
#    Número de Alunos no Intermediário  Número de Alunos no Adequado IDE EF MT  \
# 0                                  -                             -         -
# 1                                  -                             -         -
# 2                                  -                             -         -
# 3                                  -                             -         -
# 4                                  -                             -         -
#
#   IDE Médio EF
# 0            -
# 1            -
# 2            -
# 3            -
# 4            -
#
# [5 rows x 29 columns]

# %%
# Exibe os nomes das colunas do DataFrame para verificação
print("Colunas existentes antes da remoção:")
print(dfCeara.columns)

# Lista das colunas que você gostaria de excluir
colunas_para_remover = [
    'Código da Etapa', 
    'Código da Rede', 
    'Código do Município', 
    'Taxa de Participação', 
    'Proficiência Padronizada', 
    'Fator de Ajuste', 
    'Número de Alunos no Muito', 
    'Número de Alunos no Crítico', 
    'Número de Alunos no Intermediário', 
    'Número de Alunos no Adequado', 
    'IDE EF MT', 
    'IDE Médio EF'
]

# Filtra as colunas que realmente existem no DataFrame
colunas_existentes = [col for col in colunas_para_remover if col in dfCeara.columns]

# Exibe as colunas que serão removidas
print("Colunas que serão removidas:")
print(colunas_existentes)

# Remove as colunas existentes
dfCeara = dfCeara.drop(colunas_existentes, axis=1)

# Exibe os nomes das colunas após a remoção para verificação
print("Colunas existentes após a remoção:")
print(dfCeara.columns)
# Out:
# Colunas existentes antes da remoção:
# Index(['Código da Etapa', 'Etapa', 'Código da Rede', 'Rede', 'Código da CREDE',
#        'CREDE', 'Código do Município', 'Município', 'Edição',
#        'Proficiência Média', 'Desvio Padrão',
#        'Indicação do Padrão de Desempenho', 'Muito Crítico', 'Crítico',
#        'Intermediário', 'Adequado', 'População', 'Alunos Efetivos',
#        'Alunos Efetivos (Ponderado)¹',
#        'Percentual de Participação (Ponderado)¹', 'Taxa de Participação',
#        'Proficiência Padronizada', 'Fator de Ajuste',
#        'Número de Alunos no Muito Crítico', 'Número de Alunos no Crítico',
#        'Número de Alunos no Intermediário', 'Número de Alunos no Adequado',
#        'IDE EF MT', 'IDE Médio EF'],
#       dtype='object')
# Colunas que serão removidas:
# ['Código da Etapa', 'Código da Rede', 'Código do Município', 'Taxa de Participação', 'Proficiência Padronizada', 'Fator de Ajuste', 'Número de Alunos no Crítico', 'Número de Alunos no Intermediário', 'Número de Alunos no Adequado', 'IDE EF MT', 'IDE Médio EF']
# Colunas existentes após a remoção:
# Index(['Etapa', 'Rede', 'Código da CREDE', 'CREDE', 'Município', 'Edição',
#        'Proficiência Média', 'Desvio Padrão',
#        'Indicação do Padrão de Desempenho', 'Muito Crítico', 'Crítico',
#        'Intermediário', 'Adequado', 'População', 'Alunos Efetivos',
#        'Alunos Efetivos (Ponderado)¹',
#        'Percentual de Participação (Ponderado)¹',
#        'Número de Alunos no Muito Crítico'],
#       dtype='object')

# %%
dfCeara.head()
# Out:
#                           Etapa      Rede Código da CREDE    CREDE  \
# 0  9º Ano do Ensino Fundamental  ESTADUAL               4  CAMOCIM
# 1  9º Ano do Ensino Fundamental  ESTADUAL               5  TIANGUA
# 2  9º Ano do Ensino Fundamental  ESTADUAL               5  TIANGUA
# 3  9º Ano do Ensino Fundamental  ESTADUAL               5  TIANGUA
# 4  9º Ano do Ensino Fundamental  ESTADUAL               6   SOBRAL
#
#              Município Edição Proficiência Média Desvio Padrão  \
# 0               GRANJA   2012        232,8831856   42,30300397
# 1  GUARACIABA DO NORTE   2012        257,5044074   45,99977114
# 2             IBIAPINA   2012        251,5616565   38,55823739
# 3         SAO BENEDITO   2012        259,7284422   46,05819258
# 4    SANTANA DO ACARAU   2012         246,787892   42,87481125
#
#   Indicação do Padrão de Desempenho Muito Crítico      Crítico Intermediário  \
# 0                           Crítico   44,59459459  36,48648649   17,56756757
# 1                           Crítico   26,82926829  46,34146341   19,51219512
# 2                           Crítico    27,5862069  41,37931034    27,5862069
# 3                           Crítico   25,51020408  37,24489796   27,55102041
# 4                           Crítico   32,25806452  45,16129032   19,35483871
#
#       Adequado  População  Alunos Efetivos Alunos Efetivos (Ponderado)¹  \
# 0  1,351351351         79               74                            -
# 1  7,317073171         42               41                            -
# 2  3,448275862         31               29                            -
# 3  9,693877551        214              196                            -
# 4  3,225806452         37               31                            -
#
#   Percentual de Participação (Ponderado)¹ Número de Alunos no Muito Crítico
# 0                             93,67088608                                 -
# 1                             97,61904762                                 -
# 2                              93,5483871                                 -
# 3                             91,58878505                                 -
# 4                             83,78378378                                 -

# %%
# Renomeia as colunas no DataFrame dfCeara
dfCeara = dfCeara.rename(columns={
    'Etapa': 'SERIE_ANO', 
    'Rede': 'REDE DE ENSINO', 
    'Município': 'MUNICIPIO', 
    'Edição': 'ANO_PROVA', 
    'Proficiência Média': 'MEDIA_PROFICIENCIA'
})

# Exibe os nomes das colunas após o renomeio para verificação
print("Colunas após o renomeio:")
print(dfCeara.columns)
# Out:
# Colunas após o renomeio:
# Index(['SERIE_ANO', 'REDE DE ENSINO', 'Código da CREDE', 'CREDE', 'MUNICIPIO',
#        'ANO_PROVA', 'MEDIA_PROFICIENCIA', 'Desvio Padrão',
#        'Indicação do Padrão de Desempenho', 'Muito Crítico', 'Crítico',
#        'Intermediário', 'Adequado', 'População', 'Alunos Efetivos',
#        'Alunos Efetivos (Ponderado)¹',
#        'Percentual de Participação (Ponderado)¹',
#        'Número de Alunos no Muito Crítico'],
#       dtype='object')

# %%
dfCeara.head()
# Out:
#                       SERIE_ANO REDE DE ENSINO Código da CREDE    CREDE  \
# 0  9º Ano do Ensino Fundamental       ESTADUAL               4  CAMOCIM
# 1  9º Ano do Ensino Fundamental       ESTADUAL               5  TIANGUA
# 2  9º Ano do Ensino Fundamental       ESTADUAL               5  TIANGUA
# 3  9º Ano do Ensino Fundamental       ESTADUAL               5  TIANGUA
# 4  9º Ano do Ensino Fundamental       ESTADUAL               6   SOBRAL
#
#              MUNICIPIO ANO_PROVA MEDIA_PROFICIENCIA Desvio Padrão  \
# 0               GRANJA      2012        232,8831856   42,30300397
# 1  GUARACIABA DO NORTE      2012        257,5044074   45,99977114
# 2             IBIAPINA      2012        251,5616565   38,55823739
# 3         SAO BENEDITO      2012        259,7284422   46,05819258
# 4    SANTANA DO ACARAU      2012         246,787892   42,87481125
#
#   Indicação do Padrão de Desempenho Muito Crítico      Crítico Intermediário  \
# 0                           Crítico   44,59459459  36,48648649   17,56756757
# 1                           Crítico   26,82926829  46,34146341   19,51219512
# 2                           Crítico    27,5862069  41,37931034    27,5862069
# 3                           Crítico   25,51020408  37,24489796   27,55102041
# 4                           Crítico   32,25806452  45,16129032   19,35483871
#
#       Adequado  População  Alunos Efetivos Alunos Efetivos (Ponderado)¹  \
# 0  1,351351351         79               74                            -
# 1  7,317073171         42               41                            -
# 2  3,448275862         31               29                            -
# 3  9,693877551        214              196                            -
# 4  3,225806452         37               31                            -
#
#   Percentual de Participação (Ponderado)¹ Número de Alunos no Muito Crítico
# 0                             93,67088608                                 -
# 1                             97,61904762                                 -
# 2                              93,5483871                                 -
# 3                             91,58878505                                 -
# 4                             83,78378378                                 -

# %%
# Substituir vírgulas por pontos para interpretar como decimais
dfCeara['MEDIA_PROFICIENCIA'] = dfCeara['MEDIA_PROFICIENCIA'].str.replace(',', '.')

# Converter a coluna para numérico (float)
dfCeara['MEDIA_PROFICIENCIA'] = pd.to_numeric(dfCeara['MEDIA_PROFICIENCIA'], errors='coerce')

# %%
# Valor mínimo considerando apenas valores maiores que 100
minimo = dfCeara['MEDIA_PROFICIENCIA'][dfCeara['MEDIA_PROFICIENCIA'] > 100].min()

# Valor máximo
maximo = dfCeara['MEDIA_PROFICIENCIA'].max()

# Soma dos valores
soma = dfCeara['MEDIA_PROFICIENCIA'].sum()

# Média dos valores
media = dfCeara['MEDIA_PROFICIENCIA'].mean()

print(f"""Menor Média Ceará: {minimo}
Maior Média Ceará: {maximo}
Soma das Médias: {soma}
Média de Proficiência Ceará 2023: {media}""")
# Out:
# Menor Média Ceará: 213.7792813
# Maior Média Ceará: 390.4152852
# Soma das Médias: 750717.7572719001
# Média de Proficiência Ceará 2023: 260.39464352129727

# %%
import matplotlib.pyplot as plt

# Dados a serem plotados (média, máximo, mínimo)
valores = [media, maximo, minimo]
labels = ['Média', 'Máximo', 'Mínimo']

# Criar o gráfico de barras
plt.figure(figsize=(8, 5))
plt.bar(labels, valores, color=['skyblue', 'green', 'red'])

# Adicionar título e rótulos
plt.title('Média, Máximo e Mínimo da Proficiência Ceará 2023')
plt.ylabel('Valores')

# Exibir o gráfico
plt.show()

# %%
# Calcular a média de proficiência por tipo de rede
media_por_rede = dfCeara.groupby('REDE DE ENSINO')['MEDIA_PROFICIENCIA'].mean()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Criar gráfico de barras
plt.figure(figsize=(8, 5))
media_por_rede.plot(kind='bar', color=['blue', 'orange'])

# Adicionar título e rótulos
plt.title('Comparação da Média de Proficiência IDE - CE 2023: Rede Estadual vs Rede Municipal')
plt.ylabel('Média de Proficiência por Rede de Ensino')
plt.xlabel('MODADALIDADE DE REDE DE ENSINO')

# Adicionar valores em cima das barras
for index, value in enumerate(media_por_rede):
    plt.text(index, value, round(value, 2), ha='center', va='bottom')

# Exibir o gráfico
plt.xticks(rotation=0)  # Para manter os rótulos na horizontal
plt.tight_layout()  # Para ajustar o layout
plt.show()

# %%
# Filtrar para manter apenas o 9º ano no DataFrame dfSaresp
dfSaresp = dfSaresp[dfSaresp['SERIE_ANO'] == '9º Ano EF']
print(dfSaresp)
# Out:
#       REDE DE ENSINO       MUNICIPIO  SERIE_ANO PERIODO COMPONENTE_CURRICULAR  \
# 0      Rede Estadual       SAO PAULO  9º Ano EF   GERAL            MATEMÁTICA
# 1      Rede Estadual      ADAMANTINA  9º Ano EF   MANHÃ            MATEMÁTICA
# 2      Rede Estadual      ADAMANTINA  9º Ano EF   GERAL            MATEMÁTICA
# 7      Rede Estadual           AGUAI  9º Ano EF   MANHÃ            MATEMÁTICA
# 8      Rede Estadual           AGUAI  9º Ano EF   TARDE            MATEMÁTICA
# ...              ...             ...        ...     ...                   ...
# 5300  Rede Municipal         UBARANA  9º Ano EF   GERAL            MATEMÁTICA
# 5306  Rede Municipal          VARGEM  9º Ano EF   MANHÃ            MATEMÁTICA
# 5307  Rede Municipal          VARGEM  9º Ano EF   GERAL            MATEMÁTICA
# 5371  Rede Municipal  GAVIAO PEIXOTO  9º Ano EF   MANHÃ            MATEMÁTICA
# 5372  Rede Municipal  GAVIAO PEIXOTO  9º Ano EF   GERAL            MATEMÁTICA
#
#       MEDIA_PROFICIENCIA
# 0                  242.0
# 1                  255.8
# 2                  255.8
# 7                  241.4
# 8                  249.6
# ...                  ...
# 5300               250.5
# 5306               239.0
# 5307               239.0
# 5371               253.4
# 5372               253.4
#
# [1384 rows x 6 columns]

# %%
# Filtrar para manter apenas o 9º ano no DataFrame dfSaresp
dfSaresp = dfSaresp[dfSaresp['COMPONENTE_CURRICULAR'] == 'MATEMÁTICA']
print(dfSaresp)
# Out:
#       REDE DE ENSINO       MUNICIPIO  SERIE_ANO PERIODO COMPONENTE_CURRICULAR  \
# 0      Rede Estadual       SAO PAULO  9º Ano EF   GERAL            MATEMÁTICA
# 1      Rede Estadual      ADAMANTINA  9º Ano EF   MANHÃ            MATEMÁTICA
# 2      Rede Estadual      ADAMANTINA  9º Ano EF   GERAL            MATEMÁTICA
# 7      Rede Estadual           AGUAI  9º Ano EF   MANHÃ            MATEMÁTICA
# 8      Rede Estadual           AGUAI  9º Ano EF   TARDE            MATEMÁTICA
# ...              ...             ...        ...     ...                   ...
# 5300  Rede Municipal         UBARANA  9º Ano EF   GERAL            MATEMÁTICA
# 5306  Rede Municipal          VARGEM  9º Ano EF   MANHÃ            MATEMÁTICA
# 5307  Rede Municipal          VARGEM  9º Ano EF   GERAL            MATEMÁTICA
# 5371  Rede Municipal  GAVIAO PEIXOTO  9º Ano EF   MANHÃ            MATEMÁTICA
# 5372  Rede Municipal  GAVIAO PEIXOTO  9º Ano EF   GERAL            MATEMÁTICA
#
#       MEDIA_PROFICIENCIA
# 0                  242.0
# 1                  255.8
# 2                  255.8
# 7                  241.4
# 8                  249.6
# ...                  ...
# 5300               250.5
# 5306               239.0
# 5307               239.0
# 5371               253.4
# 5372               253.4
#
# [1384 rows x 6 columns]

# %%
# Realizar o join novamente
df_join = pd.merge(dfSaresp[['SERIE_ANO', 'MEDIA_PROFICIENCIA']],
dfCeara[['SERIE_ANO', 'MEDIA_PROFICIENCIA']],
on='SERIE_ANO',
suffixes=('_Saresp', '_Ceara'),
how='inner')  # Mude conforme necessário

# Exibir o DataFrame resultante
print(df_join.head())
# Out:
# Empty DataFrame
# Columns: [SERIE_ANO, MEDIA_PROFICIENCIA_Saresp, MEDIA_PROFICIENCIA_Ceara]
# Index: []

# %%
# Calcular a média de proficiência
media_saresp = dfSaresp['MEDIA_PROFICIENCIA'].mean()
media_ceara = dfCeara['MEDIA_PROFICIENCIA'].mean()

print(f"Média Saresp: {media_saresp}")
print(f"Média Ceará: {media_ceara}")
# Out:
# Média Saresp: 236.0599710982659
# Média Ceará: 260.39464352129727

# %%
import matplotlib.pyplot as plt

# Criar dados para o gráfico
labels = ['São Paulo', 'Ceará']
medias = [media_saresp, media_ceara]

# Criar o gráfico de barras
plt.figure(figsize=(8, 5))
plt.bar(labels, medias, color=['blue', 'orange'])
plt.ylabel('Média de Proficiência')
plt.title('Comparação das Médias de Proficiência entre São Paulo e Ceará')
plt.ylim(0, max(medias) + 10)  # Ajustar o limite do eixo y para melhor visualização
plt.show()

# %%
dfSaresp.to_csv('dfSaresp.csv', index=False, encoding='utf-8-sig')

# %%
dfSaresp.to_csv('C:\\Users\\alfac\\OneDrive\\Desktop\\dfSaresp.csv', index=False)

# %%
dfCeara.to_csv('C:\\Users\\alfac\\OneDrive\\Desktop\\dfCeara.csv', index=False)
