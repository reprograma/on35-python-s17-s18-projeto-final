# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Microdados.csv', delimiter=';', encoding='utf-8')

# %%
df.dtypes
# Out:
# MUNICÍPIO DO FATO      object
# REGIAO GEOGRÁFICA      object
# NATUREZA               object
# DATA DO FATO           object
# ANO                     int64
# SEXO                   object
# IDADE SENASP           object
# TOTAL DE ENVOLVIDOS     int64
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of              MUNICÍPIO DO FATO REGIAO GEOGRÁFICA  \
# 0        AFOGADOS DA INGAZEIRA            SERTÃO
# 1                      AFRANIO            SERTÃO
# 2                      AFRANIO            SERTÃO
# 3                  AGUAS BELAS           AGRESTE
# 4                    ALAGOINHA           AGRESTE
# ...                        ...               ...
# 345679                TRINDADE            SERTÃO
# 345680                 TRIUNFO            SERTÃO
# 345681                 TRIUNFO            SERTÃO
# 345682               VERTENTES           AGRESTE
# 345683  VITORIA DE SANTO ANTAO      ZONA DA MATA
#
#                                                  NATUREZA DATA DO FATO   ANO  \
# 0                INJÚRIA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   01/01/2015  2015
# 1                 AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   01/01/2015  2015
# 2         LESÃO CORPORAL POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   01/01/2015  2015
# 3       ESTUPRO DE VULNERÁVEL POR VIOLÊNCIA DOMÉSTICA/...   01/01/2015  2015
# 4                 AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   01/01/2015  2015
# ...                                                   ...          ...   ...
# 345679            AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   31/08/2024  2024
# 345680            AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   31/08/2024  2024
# 345681    LESÃO CORPORAL POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   31/08/2024  2024
# 345682    LESÃO CORPORAL POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   31/08/2024  2024
# 345683            AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   31/08/2024  2024
#
#              SEXO IDADE SENASP  TOTAL DE ENVOLVIDOS
# 0        FEMININO     6) 35-64                    1
# 1        FEMININO     5) 30-34                    1
# 2        FEMININO     4) 25-29                    1
# 3        FEMININO     2) 12-17                    1
# 4        FEMININO     6) 35-64                    1
# ...           ...          ...                  ...
# 345679  MASCULINO     6) 35-64                    1
# 345680   FEMININO     5) 30-34                    1
# 345681   FEMININO     5) 30-34                    1
# 345682   FEMININO     3) 18-24                    1
# 345683   FEMININO     6) 35-64                    1
#
# [345684 rows x 8 columns]>

# %%
#Mostrar as 5 primeiras linhas do dataframe
df.head()
# Out:
#        MUNICÍPIO DO FATO REGIAO GEOGRÁFICA  \
# 0  AFOGADOS DA INGAZEIRA            SERTÃO
# 1                AFRANIO            SERTÃO
# 2                AFRANIO            SERTÃO
# 3            AGUAS BELAS           AGRESTE
# 4              ALAGOINHA           AGRESTE
#
#                                             NATUREZA DATA DO FATO   ANO  \
# 0           INJÚRIA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   01/01/2015  2015
# 1            AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   01/01/2015  2015
# 2    LESÃO CORPORAL POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   01/01/2015  2015
# 3  ESTUPRO DE VULNERÁVEL POR VIOLÊNCIA DOMÉSTICA/...   01/01/2015  2015
# 4            AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   01/01/2015  2015
#
#        SEXO IDADE SENASP  TOTAL DE ENVOLVIDOS
# 0  FEMININO     6) 35-64                    1
# 1  FEMININO     5) 30-34                    1
# 2  FEMININO     4) 25-29                    1
# 3  FEMININO     2) 12-17                    1
# 4  FEMININO     6) 35-64                    1

# %%
#Exibir as 5 últimas linhas
df.tail()
# Out:
#              MUNICÍPIO DO FATO REGIAO GEOGRÁFICA  \
# 345679                TRINDADE            SERTÃO
# 345680                 TRIUNFO            SERTÃO
# 345681                 TRIUNFO            SERTÃO
# 345682               VERTENTES           AGRESTE
# 345683  VITORIA DE SANTO ANTAO      ZONA DA MATA
#
#                                                NATUREZA DATA DO FATO   ANO  \
# 345679          AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   31/08/2024  2024
# 345680          AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   31/08/2024  2024
# 345681  LESÃO CORPORAL POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   31/08/2024  2024
# 345682  LESÃO CORPORAL POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   31/08/2024  2024
# 345683          AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR   31/08/2024  2024
#
#              SEXO IDADE SENASP  TOTAL DE ENVOLVIDOS
# 345679  MASCULINO     6) 35-64                    1
# 345680   FEMININO     5) 30-34                    1
# 345681   FEMININO     5) 30-34                    1
# 345682   FEMININO     3) 18-24                    1
# 345683   FEMININO     6) 35-64                    1

# %%
#Reduzindo o dataframe apenas às colunas selecionadas
df = df[['REGIAO GEOGRÁFICA', 'NATUREZA', 'ANO', 'SEXO', 'IDADE SENASP']]
df
# Out:
#        REGIAO GEOGRÁFICA                                           NATUREZA  \
# 0                 SERTÃO           INJÚRIA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR
# 1                 SERTÃO            AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR
# 2                 SERTÃO    LESÃO CORPORAL POR VIOLÊNCIA DOMÉSTICA/FAMILIAR
# 3                AGRESTE  ESTUPRO DE VULNERÁVEL POR VIOLÊNCIA DOMÉSTICA/...
# 4                AGRESTE            AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR
# ...                  ...                                                ...
# 345679            SERTÃO            AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR
# 345680            SERTÃO            AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR
# 345681            SERTÃO    LESÃO CORPORAL POR VIOLÊNCIA DOMÉSTICA/FAMILIAR
# 345682           AGRESTE    LESÃO CORPORAL POR VIOLÊNCIA DOMÉSTICA/FAMILIAR
# 345683      ZONA DA MATA            AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR
#
#          ANO       SEXO IDADE SENASP
# 0       2015   FEMININO     6) 35-64
# 1       2015   FEMININO     5) 30-34
# 2       2015   FEMININO     4) 25-29
# 3       2015   FEMININO     2) 12-17
# 4       2015   FEMININO     6) 35-64
# ...      ...        ...          ...
# 345679  2024  MASCULINO     6) 35-64
# 345680  2024   FEMININO     5) 30-34
# 345681  2024   FEMININO     5) 30-34
# 345682  2024   FEMININO     3) 18-24
# 345683  2024   FEMININO     6) 35-64
#
# [345684 rows x 5 columns]

# %%
#isnull() é utilizado para identificar se há valores nulos no dataframe
df_nulos = df.isnull().sum()
df_nulos
# Out:
# REGIAO GEOGRÁFICA    0
# NATUREZA             0
# ANO                  0
# SEXO                 0
# IDADE SENASP         0
# dtype: int64

# %%
#Retorna a quantidade de linhas e colunas do DataFrame
df.shape
# Out:
# (345684, 5)

# %%
df = df.rename(columns={'IDADE SENASP': 'IDADE'})

# %%
df.head(10)
# Out:
#   REGIAO GEOGRÁFICA                                           NATUREZA   ANO  \
# 0            SERTÃO           INJÚRIA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR  2015
# 1            SERTÃO            AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR  2015
# 2            SERTÃO    LESÃO CORPORAL POR VIOLÊNCIA DOMÉSTICA/FAMILIAR  2015
# 3           AGRESTE  ESTUPRO DE VULNERÁVEL POR VIOLÊNCIA DOMÉSTICA/...  2015
# 4           AGRESTE            AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR  2015
# 5           AGRESTE         DIFAMAÇÃO POR VIOLÊNCIA DOMÉSTICA/FAMILIAR  2015
# 6      ZONA DA MATA    LESÃO CORPORAL POR VIOLÊNCIA DOMÉSTICA/FAMILIAR  2015
# 7           AGRESTE    LESÃO CORPORAL POR VIOLÊNCIA DOMÉSTICA/FAMILIAR  2015
# 8           AGRESTE    LESÃO CORPORAL POR VIOLÊNCIA DOMÉSTICA/FAMILIAR  2015
# 9           AGRESTE            AMEAÇA POR VIOLÊNCIA DOMÉSTICA/FAMILIAR  2015
#
#        SEXO     IDADE
# 0  FEMININO  6) 35-64
# 1  FEMININO  5) 30-34
# 2  FEMININO  4) 25-29
# 3  FEMININO  2) 12-17
# 4  FEMININO  6) 35-64
# 5  FEMININO  6) 35-64
# 6  FEMININO  5) 30-34
# 7  FEMININO  6) 35-64
# 8  FEMININO  3) 18-24
# 9  FEMININO  5) 30-34

# %%
# Filtrando o dataframe
df_filtrado = df[(df['ANO'].between(2022, 2024)) & 
                 (df['REGIAO GEOGRÁFICA'] == 'RECIFE') & 
                 (~df['SEXO'].isin(['NAO INFORMADO', 'DESCONHECIDO']))]

fig, axs = plt.subplots(figsize=(10, 7))

sns.countplot(x='ANO', data=df_filtrado, palette='Blues')

plt.title('Total de casos de violência por gênero - Recife', fontsize=18, fontweight='bold')
axs.set_xlabel(' ', fontsize=12, fontweight='bold')
axs.set_ylabel(' ', fontsize=12, fontweight='bold')

# Adicionando as anotações
df_counts = df_filtrado.groupby(['ANO', 'SEXO']).size()
for (ano, sexo), v in df_counts.items():
    axs.annotate(f"{v:.2f}", (ano, v), ha='center', va='bottom')

plt.show()
# Out:
# C:\Users\rayan\AppData\Local\Temp\ipykernel_19564\3616829973.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='ANO', data=df_filtrado, palette='Blues')

# %%
# Filtra o DataFrame por ano
df_filtrado = df[(df['ANO'].between(2022, 2024)) & (df['REGIAO GEOGRÁFICA'] == 'RECIFE')]

# Inicializa a matplotlib figure
fig, axs = plt.subplots(figsize=(10, 7))

sns.countplot(x='ANO', data=df_filtrado, palette='Blues')
plt.title('Total de casos de violência por ano - Recife', fontsize=18, fontweight='bold')
axs.set_xlabel(' ', fontsize=12, fontweight='bold')
axs.set_ylabel(' ', fontsize=12, fontweight='bold')

# Contagem e anotação
df_counts = df_filtrado.groupby(['ANO']).size()
for (ano), v in df_counts.items():
    axs.annotate(f"{v:.2f}", (ano, v), ha='center', va='bottom')

plt.show()
# Out:
# C:\Users\rayan\AppData\Local\Temp\ipykernel_19564\118714134.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='ANO', data=df_filtrado, palette='Blues')

# %%
# Filtra o DataFrame
df_filtrado = df[(df['ANO'].between(2022, 2024)) & 
                 (df['REGIAO GEOGRÁFICA'] == 'RECIFE') & 
                 (~df['SEXO'].isin(['NAO INFORMADO', 'DESCONHECIDO', '(vazio)'])) & 
                 (~df['IDADE'].isin(['(vazio)']))]

# Inicializa a matplotlib figure
fig, axs = plt.subplots(figsize=(12, 7))

# Verifica se 'IDADE' está no formato correto (se necessário, converte para categórico)
if df_filtrado['IDADE'].dtype != 'category':
    df_filtrado['IDADE'] = df_filtrado['IDADE'].astype('category')

# Cria um gráfico de contagem agrupado por ANO e IDADE 
sns.countplot(x='ANO', hue='IDADE', data=df_filtrado, palette='Blues')

plt.title('Total de casos de violência por idade - Recife', fontsize=18, fontweight='bold')
axs.set_xlabel('Ano', fontsize=12, fontweight='bold')
axs.set_ylabel('Total', fontsize=12, fontweight='bold')

# Contagem e anotação
df_counts = df_filtrado.groupby(['ANO', 'IDADE']).size()
for (ano, idade), v in df_counts.items():
    axs.annotate(f"{v:.2f}", (ano, v), ha='center', va='bottom')

plt.legend(title='Idade')
plt.show()
# Out:
# C:\Users\rayan\AppData\Local\Temp\ipykernel_19564\3653632960.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado['IDADE'] = df_filtrado['IDADE'].astype('category')
# C:\Users\rayan\AppData\Local\Temp\ipykernel_19564\3653632960.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_counts = df_filtrado.groupby(['ANO', 'IDADE']).size()

# %%
# Gráfico de Barras: Tipos de Violência
natureza_counts = df['NATUREZA'].value_counts()

plt.figure(figsize=(12, 6))
sns.barplot(x=natureza_counts.values, y=natureza_counts.index, palette="Blues")
plt.title("Quantidade de Atendimentos por Tipo de Violência Doméstica")
plt.xlabel("Número de Atendimentos")
plt.ylabel("Tipo de Violência")
plt.show()
# Out:
# C:\Users\rayan\AppData\Local\Temp\ipykernel_19564\509045586.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=natureza_counts.values, y=natureza_counts.index, palette="Blues")

# %%
# Salvar a base filtrada em um novo arquivo CSV
df_filtrado.to_csv('base_filtrada.csv', index=False)

# %%
# Salvar a base filtrada com codificação UTF-8
df_filtrado.to_csv('base_filtrada.csv', index=False, encoding='utf-8')
